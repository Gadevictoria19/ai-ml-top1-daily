# %%
print("Hello")

# %%
numbers=[10,12,13,16,18]
new_list=[number for number in numbers if number%2==0]
print(new_list)
# Out:
# [10, 12, 16, 18]

# %%
numbers=[2,5,7,1,9]
power=[2**x for x in numbers]
print(power)
# Out:
# [4, 32, 128, 2, 512]

# %%
words=["uday","victoria","rohith"]
words=[word.upper()  for word in words if word.startswith('v')]
print(words)
# Out:
# ['VICTORIA']

# %%
def myfn(x:int):
    return x
myfn(12)
# Out:
# 12

# %%
def uhh(list:int ):
    return list

# %%
class Person:
    def __init__(self, name: str, age: int, job: str):
        self.name = name
        self.age = age
        self.job = job
